# %%
import h5py
import matplotlib.pyplot as plt

# %%
dset = h5py.File('/home/nina/Documents/hockey_tracking/number_recognition/SynthText/data/testout.h5', 'r')
names = sorted(dset['image'].keys())
nameImg = names[0]

# %%
img = dset['image'][nameImg]
plt.imshow(img)
plt.show()
print(img.shape)
# Out:
# (78, 60, 3)

# %%
seg = dset['seg'][nameImg]
plt.imshow(seg.value * 255, cmap='gray')
plt.show()
print(seg.shape)
# Out:
# (157, 121)

# %%
depths = dset['depth'][nameImg]
depth1 = depths[0].T
depth2 = depths[1].T
plt.subplot(1, 2, 1), plt.imshow(depth1)
plt.subplot(1, 2, 2), plt.imshow(depth2, cmap='gray')
plt.show()
